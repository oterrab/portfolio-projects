# %% [markdown]
# <a href="https://colab.research.google.com/github/oterrab/portfolio-projects/blob/main/python/basedosdados/bases/br_mec_sisu/code/eda_architeture_espera.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EDA to build database architeture

# %%
import pandas as pd
import glob
from tqdm.auto import tqdm
import time
from dask import dataframe as dd

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
files = []

for filepath in glob.iglob(r'/content/gdrive/MyDrive/bases/br_mec_sisu/input/espera/*.csv'):
    files.append(filepath)

anos=[]

for i in range(len(files)) : 
  anos.append(files[i][-10:-4])

dict_ano = dict(zip(anos, files))
dict_ano
# Out:
# {'2020-1': '/content/gdrive/MyDrive/bases/br_mec_sisu/input/espera/ListagemListaEspera_2020-1.csv',
#  '2021-1': '/content/gdrive/MyDrive/bases/br_mec_sisu/input/espera/ListagemListaEspera_2021-1.csv',
#  '2018-2': '/content/gdrive/MyDrive/bases/br_mec_sisu/input/espera/ListagemListaEspera_2018-2.csv',
#  '2020-2': '/content/gdrive/MyDrive/bases/br_mec_sisu/input/espera/ListagemListaEspera_2020-2.csv',
#  '2019-2': '/content/gdrive/MyDrive/bases/br_mec_sisu/input/espera/ListagemListaEspera_2019-2.csv',
#  '2019-1': '/content/gdrive/MyDrive/bases/br_mec_sisu/input/espera/ListagemListaEspera_2019-1.csv',
#  '2017-2': '/content/gdrive/MyDrive/bases/br_mec_sisu/input/espera/ListagemListaEspera_2017-2.csv',
#  '2017-1': '/content/gdrive/MyDrive/bases/br_mec_sisu/input/espera/ListagemListaEspera_2017-1.csv'}

# %%
start = time.time()
dfs = []
for key in tqdm(dict_ano):
    df = dd.read_csv(dict_ano[key], sep="|", encoding='latin-1', header=0, dtype='string')
    dfs.append(df)
    print("Read ", key)
end = time.time()
print("Read ", len(dict_ano[key])," csv files with dask: ",((end-start)/60),"min")
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
# Read  2020-1
# Read  2021-1
# Read  2018-2
# Read  2020-2
# Read  2019-2
# Read  2019-1
# Read  2017-2
# Read  2017-1
# Read  85  csv files with dask:  0.04376823504765828 min

# %%
print(len(dfs))
# Out:
# 8

# %%
dfs[1].head(5)
# Out:
#   NU_ANO NU_EDICAO CO_ETAPA         DS_ETAPA CO_IES  \
# 0   2021         1        7  LISTA DE ESPERA      3
# 1   2021         1        7  LISTA DE ESPERA      3
# 2   2021         1        7  LISTA DE ESPERA      3
# 3   2021         1        7  LISTA DE ESPERA      3
# 4   2021         1        7  LISTA DE ESPERA      3
#
#                             NO_IES SIGLA_IES SG_UF_IES CO_CAMPUS  \
# 0  UNIVERSIDADE FEDERAL DE SERGIPE       UFS        SE   1006435
# 1  UNIVERSIDADE FEDERAL DE SERGIPE       UFS        SE   1006435
# 2  UNIVERSIDADE FEDERAL DE SERGIPE       UFS        SE   1006435
# 3  UNIVERSIDADE FEDERAL DE SERGIPE       UFS        SE   1006435
# 4  UNIVERSIDADE FEDERAL DE SERGIPE       UFS        SE   1006435
#
#       NO_CAMPUS  ... NU_NOTA_R NOTA_L_COM_PESO NOTA_CH_COM_PESO  \
# 0  Unidade SEDE  ...       780          1148,6           760,65
# 1  Unidade SEDE  ...       600          1085,4            773,1
# 2  Unidade SEDE  ...       500          1055,4              801
# 3  Unidade SEDE  ...       660          1137,4              801
# 4  Unidade SEDE  ...       760          1088,8            700,5
#
#   NOTA_CN_COM_PESO NOTA_M_COM_PESO NOTA_R_COM_PESO NU_NOTA_CANDIDATO  \
# 0             1206          736,95            1560            541,22
# 1           1698,6          604,95            1200            536,21
# 2           1317,6          688,05            1000            486,21
# 3           1578,9          725,85            1320            556,32
# 4           1551,3           718,2            1520            557,88
#
#   NU_NOTACORTE NU_CLASSIFICACAO ST_APROVADO
# 0       572,54               11           S
# 1       572,54               13           S
# 2        585,9               46           S
# 3       606,06               18           S
# 4        585,9               12           S
#
# [5 rows x 52 columns]

# %%
print(' '.join(list(dfs[1].columns)))

## copy and paste into excel
# Out:
# NU_ANO NU_EDICAO CO_ETAPA DS_ETAPA CO_IES NO_IES SIGLA_IES SG_UF_IES CO_CAMPUS NO_CAMPUS SG_UF_CAMPUS NO_MUNUCIPIO_CAMPUS CO_IES_CURSO NO_CURSO DS_GRAU DS_TURNO TP_MOD_CONCORRENCIA DS_MOD_CONCORRENCIA NU_PERCENTUAL_BONUS NU_PESO_L NU_PESO_CH NU_PESO_CN NU_PESO_M NU_PESO_R NOTA_MINIMA_L NOTA_MINIMA_CH NOTA_MINIMA_CN NOTA_MINIMA_M NOTA_MINIMA_R MEDIA_MINIMA NU_CPF CO_INSCRICAO_ENEM NO_INSCRITO TP_SEXO DT_NASCIMENTO SG_UF_CANDIDATO MUNICIPIO_CANDIDATO ST_OPCAO NU_NOTA_L NU_NOTA_CH NU_NOTA_CN NU_NOTA_M NU_NOTA_R NOTA_L_COM_PESO NOTA_CH_COM_PESO NOTA_CN_COM_PESO NOTA_M_COM_PESO NOTA_R_COM_PESO NU_NOTA_CANDIDATO NU_NOTACORTE NU_CLASSIFICACAO ST_APROVADO

# %% [markdown]
# ## Get unique values of columns

# %%
dfs[3].ST_APROVADO.head(5)
# Out:
# 0    N
# 1    N
# 2    N
# 3    N
# 4    N
# Name: ST_APROVADO, dtype: string

# %%
for i in tqdm(range(len(dfs))):
  ano = dfs[i]['NU_ANO'].head(1).item()
  semestre = dfs[i]['NU_EDICAO'].head(1).item()
  print('For ' + ano + '-' + semestre + ':')
  for unique_value in dfs[i].ST_APROVADO.unique().compute():
    print('\n ' + unique_value)
  print("------------------")
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
# For 2018-2:
#
#  N
#
#  S
# ------------------
# For 2019-1:
#
#  N
#
#  S
# ------------------
# For 2019-2:
#
#  N
#
#  S
# ------------------
# For 2017-1:
#
#  N
#
#  S
# ------------------
# For 2017-2:
#
#  N
#
#  S
# ------------------
# For 2020-1:
#
#  N
#
#  S
# ------------------
# For 2020-2:
#
#  S
#
#  N
# ------------------
# For 2021-1:
#
#  N
#
#  S
# ------------------
